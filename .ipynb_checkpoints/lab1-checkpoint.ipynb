# %%
import urllib

# %%
data_link = urllib.request.urlopen('https://people.sc.fsu.edu/~jburkardt/datasets/regression/x28.txt')

# %%
data = data_link.readlines()

# %%
data
# Out:
# [b'#  x28.txt\n',
#  b'#\n',
#  b'#  Discussion:\n',
#  b'#\n',
#  b'#    The death rate is to be represented as a function of other variables.\n',
#  b'#\n',
#  b'#    There are 60 rows of data.  The data includes:\n',
#  b'#\n',
#  b'#      I,   the index;\n',
#  b'#      A1,  the average annual precipitation;\n',
#  b'#      A2,  the average January temperature;\n',
#  b'#      A3,  the average July temperature;\n',
#  b'#      A4,  the size of the population older than 65;\n',
#  b'#      A5,  the number of members per household;\n',
#  b'#      A6,  the number of years of schooling for persons over 22;\n',
#  b'#      A7,  the number of households with fully equipped kitchens;\n',
#  b'#      A8,  the population per square mile; \n',
#  b'#      A9,  the size of the nonwhite population;\n',
#  b'#      A10, the number of office workers;\n',
#  b'#      A11, the number of families with an income less than $3000;\n',
#  b'#      A12, the hydrocarbon pollution index;\n',
# ...

# %%
input_data = []
for item in data:
    input_data.append(item.decode('utf-8'))

# %%
input_data
# Out:
# ['#  x28.txt\n',
#  '#\n',
#  '#  Discussion:\n',
#  '#\n',
#  '#    The death rate is to be represented as a function of other variables.\n',
#  '#\n',
#  '#    There are 60 rows of data.  The data includes:\n',
#  '#\n',
#  '#      I,   the index;\n',
#  '#      A1,  the average annual precipitation;\n',
#  '#      A2,  the average January temperature;\n',
#  '#      A3,  the average July temperature;\n',
#  '#      A4,  the size of the population older than 65;\n',
#  '#      A5,  the number of members per household;\n',
#  '#      A6,  the number of years of schooling for persons over 22;\n',
#  '#      A7,  the number of households with fully equipped kitchens;\n',
#  '#      A8,  the population per square mile; \n',
#  '#      A9,  the size of the nonwhite population;\n',
#  '#      A10, the number of office workers;\n',
#  '#      A11, the number of families with an income less than $3000;\n',
#  '#      A12, the hydrocarbon pollution index;\n',
# ...

# %%
input_data.index(' 1  36  27  71   8.1  3.34  11.4  81.5  3243   8.8  42.6  11.7   21   15   59  59   921.870\n')
# Out:
# 72

# %%
input_data = input_data[72:]

# %%
input_data
# Out:
# [' 1  36  27  71   8.1  3.34  11.4  81.5  3243   8.8  42.6  11.7   21   15   59  59   921.870\n',
#  ' 2  35  23  72  11.1  3.14  11.0  78.8  4281   3.6  50.7  14.4    8   10   39  57   997.875\n',
#  ' 3  44  29  74  10.4  3.21   9.8  81.6  4260   0.8  39.4  12.4    6    6   33  54   962.354\n',
#  ' 4  47  45  79   6.5  3.41  11.1  77.5  3125  27.1  50.2  20.6   18    8   24  56   982.291\n',
#  ' 5  43  35  77   7.6  3.44   9.6  84.6  6441  24.4  43.7  14.3   43   38  206  55  1071.289\n',
#  ' 6  53  45  80   7.7  3.45  10.2  66.8  3325  38.5  43.1  25.5   30   32   72  54  1030.380\n',
#  ' 7  43  30  74  10.9  3.23  12.1  83.9  4679   3.5  49.2  11.3   21   32   62  56   934.700\n',
#  ' 8  45  30  73   9.3  3.29  10.6  86.0  2140   5.3  40.4  10.5    6    4    4  56   899.529\n',
#  ' 9  36  24  70   9.0  3.31  10.5  83.2  6582   8.1  42.5  12.6   18   12   37  61  1001.902\n',
#  '10  36  27  72   9.5  3.36  10.7  79.3  4213   6.7  41.0  13.2   12    7   20  59   912.347\n',
# ...

# %%
input_file = open('input_file.txt', 'w')
for item in input_data:
    input_file.write(item[4:])

# %%
input_file.close()
